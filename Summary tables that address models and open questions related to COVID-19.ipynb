# %% [markdown]
# # Summary tables that address models and open questions related to COVID-19

# %%
import numpy as np 
import pandas as pd 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt

# %%
# Geting the Table of Studies
articles=pd.read_csv('../metadata.csv', low_memory=False) 
articles.shape
# Out:
# (210537, 19)

# %%
# Cleaned the TABLE for readability
Art1= articles[['title','publish_time','journal','url','abstract','doi','cord_uid']]

# Make a copy to work with
Articles1=Art1.copy()

# %%
#separate each word in the column: abstract, for browsing
Articles1['words'] = Articles1.abstract.str.strip().str.split('[\W_]+')

#separate words in the abstract column and create a new column
Articles1 = Articles1[Articles1.words.str.len() > 0]
Articles1.head(3)
# Out:
#                                                title publish_time  \
# 0  Clinical features of culture-proven Mycoplasma...   2001-07-04
# 1  Nitric oxide: a pro-inflammatory mediator in l...   2000-08-15
# 2    Surfactant protein-D and pulmonary host defense   2000-08-25
#
#           journal                                                url  \
# 0  BMC Infect Dis  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1      Respir Res  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 2      Respir Res  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
#
#                                             abstract                    doi  \
# 0  OBJECTIVE: This retrospective chart review des...  10.1186/1471-2334-1-6
# 1  Inflammatory diseases of the respiratory tract...           10.1186/rr14
# 2  Surfactant protein-D (SP-D) participates in th...           10.1186/rr19
#
#    cord_uid                                              words
# 0  ug7v899j  [OBJECTIVE, This, retrospective, chart, review...
# 1  02tnwd4m  [Inflammatory, diseases, of, the, respiratory,...
# 2  ejv2xln0  [Surfactant, protein, D, SP, D, participates, ...

# %%
# saving the Table (dataframe) above
Articles1.to_csv('Articles.csv')

# %% [markdown]
# #### 1. Human immune response to COVID-19

# %%
##1 Human immune response to COVID-19
# TABLE OF abstracts related to COVID 
COVID=Articles1[Articles1['abstract'].str.contains('COVID')]
COVID.shape
# Out:
# (47272, 8)

# %%
# saving the dataframe above
COVID.to_csv('COVID_ArticleAbstracts.csv')

# %%
# Looking among COVID articles for immune response
ImmResp=COVID[COVID['abstract'].str.contains('immune response')]
ImmResp.shape
# Out:
# (1259, 8)

# %%
Human=ImmResp[ImmResp['abstract'].str.contains('human')]
Human.shape
# Out:
# (288, 8)

# %%
Human.head(3)
# Out:
#                                                    title publish_time  \
# 22218  Host Immune Response and Immunobiology of Huma...   2020-04-30
# 28761  Clinical remission of a critically ill COVID-1...   2020-07-31
# 28893  Lung microbiome and coronavirus disease 2019 (...   2020-08-05
#
#                                    journal  \
# 22218  Coronavirus Disease 2019 (COVID-19)
# 28761                 Medicine (Baltimore)
# 28893                         Hum Microb J
#
#                                                      url  \
# 22218  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 28761  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 28893  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                                                 abstract  \
# 22218  One of the most serious viral outbreaks of the...
# 28761  RATIONALE: The COVID-19 cases increased very f...
# 28893  Coronavirus disease 2019 (COVID-19) is a rapid...
#
#                                doi  cord_uid  \
# 22218  10.1007/978-981-15-4814-7_5  bwxktvsz
# 28761  10.1097/md.0000000000021429  yodji3f4
# 28893  10.1016/j.humic.2020.100073  xzlc1pni
#
#                                                    words
# 22218  [One, of, the, most, serious, viral, outbreaks...
# 28761  [RATIONALE, The, COVID, 19, cases, increased, ...
# 28893  [Coronavirus, disease, 2019, COVID, 19, is, a,...

# %%
# saving the TABLE above as a 
Human.to_csv('COVID_ArticleAbstracts_Human_Immune_Response.csv')

# %% [markdown]
# #### 2. What is known about mutations of the virus?

# %%
Mutation=Articles1[Articles1['abstract'].str.contains('mutation')]
Mutation.shape
# Out:
# (3268, 8)

# %%
coronaMut=Mutation[Mutation['abstract'].str.contains('corona')]
coronaMut.shape
# Out:
# (1068, 8)

# %%
COVIDMut=Mutation[Mutation['abstract'].str.contains('COVID')]
COVIDMut.shape
# Out:
# (457, 8)

# %%
# saving the TABLE above as a 
COVIDMut.to_csv('COVID_ArticleAbstracts_COVID_mutation.csv')

# %% [markdown]
# #### Word Cloud: About COVID mutation

# %%
#to omit:
symbols1='!@#$%&*.,?"-'
ignoreThese=['background', 'abstract',
             'our','this','the',
             'objective','since', 'name',
            'word', 'words', 'and',
            'summary', 'study', 'dtype',
            'goal']

for char in symbols1:
        words1=COVIDMut['words'].replace(char,' ')
#lower case all words
words1=str(words1)
words1=words1.lower()

#ignore words
for item in ignoreThese:
        words1=words1.replace(item, ' ') 
        
wordcloud = WordCloud(
            width = 2000,
            height = 1000,
            background_color = 'black',
            stopwords = STOPWORDS).generate(words1)
fig = plt.figure(
    figsize = (20, 10),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# #### 3. Studies to monitor potential adaptations

# %%
Adapt=COVID[COVID['abstract'].str.contains('adaptation')]
Adapt.shape
# Out:
# (475, 8)

# %%
Adapt.head(3)
# Out:
#                                                    title publish_time  \
# 10996  Practical Considerations When Performing Neuro...   2020-05-06
# 26666  Organisational changes and challenges for infl...   2020-06-15
# 27421  The impact of COVID‐19 on franchising in emerg...   2020-06-22
#
#                        journal  \
# 10996             Neurodiagn J
# 26666  Frontline Gastroenterol
# 27421                      NaN
#
#                                                      url  \
# 10996  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 26666  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 27421  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                                                 abstract  \
# 10996  The coronavirus disease 2019, SARS-COV-2 (the ...
# 26666  OBJECTIVE: To determine the challenges in diag...
# 27421  The outbreak of COVID‐19, the disease caused b...
#
#                                  doi  cord_uid  \
# 10996  10.1080/21646821.2020.1756132  72s8wpla
# 26666   10.1136/flgastro-2020-101520  pix0hmpj
# 27421              10.1002/joe.22053  0n7cidfw
#
#                                                    words
# 10996  [The, coronavirus, disease, 2019, SARS, COV, 2...
# 26666  [OBJECTIVE, To, determine, the, challenges, in...
# 27421  [The, outbreak, of, COVID, 19, the, disease, c...

# %%
Adapt.to_csv('COVID_ArticleAbstracts_COVID_adaptation.csv')

# %% [markdown]
# #### 4. Are there studies about phenotypic change?

# %%
Pheno=Articles1[Articles1['abstract'].str.contains('phenotypic change')]
Pheno.shape
# Out:
# (26, 8)

# %%
Pheno2=COVID[COVID['abstract'].str.contains('phenotypic change')]
Pheno2.shape
# Out:
# (0, 8)

# %%
Pheno.to_csv('ArticleAbstracts_studies_on_phenotypic_change.csv')

# %% [markdown]
# #### 5. Changes in COVID-19 as the virus evolves.

# %%
Evo=COVID[COVID['abstract'].str.contains('evolve')]
Evo.shape
# Out:
# (648, 8)

# %%
#searching through those article abstracts with COVID term
VirEvo=COVID[COVID['abstract'].str.contains('virus evolve')]
VirEvo.shape
# Out:
# (1, 8)

# %%
VirEvo.head(3)
# Out:
#                                                     title publish_time  \
# 125282  Flattening the curves: on-off lock-down strate...   2020-04-15
#
#        journal                                     url  \
# 125282     NaN  https://arxiv.org/pdf/2004.06916v1.pdf
#
#                                                  abstract  doi  cord_uid  \
# 125282  The current COVID-19 pandemic is affecting dif...  NaN  zhcamsqa
#
#                                                     words
# 125282  [The, current, COVID, 19, pandemic, is, affect...

# %%
VirEvo.to_csv('ArticleAbstracts_COVID_virus_evolve.csv')

# %% [markdown]
# #### 6. Regional genetic variations (mutations)

# %%
Genetic=COVID[COVID['abstract'].str.contains('genetic')]
Genetic.shape
# Out:
# (944, 8)

# %%
GeneticV=COVID[COVID['abstract'].str.contains('genetic variation')]
GeneticV.shape
# Out:
# (43, 8)

# %%
GeneticV.to_csv('ArticleAbstracts_COVID_genetic_variation.csv')

# %% [markdown]
# #### 7. What do models for transmission predict?

# %%
trans=COVID[COVID['abstract'].str.contains('transmission')]
trans.shape
# Out:
# (6043, 8)

# %%
models=trans[trans['abstract'].str.contains('model')]
models.shape
# Out:
# (1350, 8)

# %%
pred=models[models['abstract'].str.contains('predict')]
pred.shape
# Out:
# (414, 8)

# %%
pred.to_csv('ArticleAbstracts_COVID_transmission_model_predict.csv')

# %% [markdown]
# #### Word Cloud: model predictions

# %%
for char in symbols1:
        words2=pred['words'].replace(char,' ')
#lower case all words
words2=str(words2)
words2=words2.lower()

#ignore words
for item in ignoreThese:
        words2=words2.replace(item, ' ') 
        
wordcloud = WordCloud(
            width = 2000,
            height = 1000,
            background_color = 'black',
            stopwords = STOPWORDS).generate(words2)
fig = plt.figure(
    figsize = (20, 10),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# #### 8. Serial Interval (for infector-infectee pair)

# %%
SerialInt=COVID[COVID['abstract'].str.contains('virus evolve')]
SerialInt.shape
# Out:
# (1, 8)

# %%
SerialInt.head(3)
# Out:
#                                                     title publish_time  \
# 125282  Flattening the curves: on-off lock-down strate...   2020-04-15
#
#        journal                                     url  \
# 125282     NaN  https://arxiv.org/pdf/2004.06916v1.pdf
#
#                                                  abstract  doi  cord_uid  \
# 125282  The current COVID-19 pandemic is affecting dif...  NaN  zhcamsqa
#
#                                                     words
# 125282  [The, current, COVID, 19, pandemic, is, affect...

# %%
SerialInt.to_csv('ArticleAbstracts_COVID_Serial_Interval.csv')

# %% [markdown]
# #### 9. Qualitative assessment frameworks

# %%
Qual=Articles1[Articles1['abstract'].str.contains('qualitative')]
Qual.shape
# Out:
# (1569, 8)

# %%
QFrame=Qual[Qual['abstract'].str.contains('framework')]
QFrame.shape
# Out:
# (128, 8)

# %%
QFrame.to_csv('ArticleAbstracts_Qualitative_Framework.csv')
