# %%
import requests
data = requests.get('http://localhost:9200')
print(data.content)
# Out:
# b'{\n  "name" : "kaggle-task",\n  "cluster_name" : "elasticsearch",\n  "cluster_uuid" : "Adi5nq99RRWHxacAd6EnRg",\n  "version" : {\n    "number" : "7.8.1",\n    "build_flavor" : "default",\n    "build_type" : "tar",\n    "build_hash" : "b5ca9c58fb664ca8bf9e4057fc229b3396bf3a89",\n    "build_date" : "2020-07-21T16:40:44.668009Z",\n    "build_snapshot" : false,\n    "lucene_version" : "8.5.1",\n    "minimum_wire_compatibility_version" : "6.8.0",\n    "minimum_index_compatibility_version" : "6.0.0-beta1"\n  },\n  "tagline" : "You Know, for Search"\n}\n'

# %%
#connect to our cluster
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])

# %%
es.count(index='metafile')
# Out:
# {'count': 210537,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %%
es.info()
# Out:
# {'name': 'kaggle-task',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'Adi5nq99RRWHxacAd6EnRg',
#  'version': {'number': '7.8.1',
#   'build_flavor': 'default',
#   'build_type': 'tar',
#   'build_hash': 'b5ca9c58fb664ca8bf9e4057fc229b3396bf3a89',
#   'build_date': '2020-07-21T16:40:44.668009Z',
#   'build_snapshot': False,
#   'lucene_version': '8.5.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
import pandas as pd
df = pd.read_csv("../metadata.csv", low_memory=False)
df.head(3)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
# 2  PMC59549  11667972   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
df.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id'],
#       dtype='object')

# %%
result = es.search(index = "metafile",body = {
            "query": { 
                "bool": { 
                    "must": [
                        { "match": {"journal" : "J Exot Pet Med" }}
                  ],
                }
              }
            })

result
# Out:
# {'took': 25,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 20.319862,
#   'hits': [{'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'WmUN-XMBkX4i4bZkrqQK',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'Rodent Diagnostic Testing',
#      '@timestamp': '2020-08-16T20:54:48.918Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': '8rg3bv3c',
#      'authors': 'Jenkins, Jeffrey R.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC7106059.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106059/',
#      'doi': '10.1053/j.jepm.2007.12.004',
#      'host': 'kaggle-task',
#      'message': '8rg3bv3c,,PMC,Rodent Diagnostic Testing,10.1053/j.jepm.2007.12.004,PMC7106059,,no-cc,"Clinical medicine is an important part of scientific medicine that is all too often neglected when treating rodents and small mammal pets. As with more traditional pets, a progressive diagnostic regimen should include a thorough history, clinical signs, physical examination, and laboratory findings.",2008-03-21,"Jenkins, Jeffrey R.",J Exot Pet Med,,,,,document_parses/pmc_json/PMC7106059.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106059/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7106059',
#      'abstract': 'Clinical medicine is an important part of scientific medicine that is all too often neglected when treating rodents and small mammal pets. As with more traditional pets, a progressive diagnostic regimen should include a thorough history, clinical signs, physical examination, and laboratory findings.',
#      'publish_time': '2008-03-21',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'XGUN-XMBkX4i4bZkrqQK',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'Paraplegia in a Domestic Ferret (Mustela Putorius Furo) Secondary to Metastatic Adrenocortical Carcinoma with Myxoid Differentiation',
#      '@timestamp': '2020-08-16T20:54:48.918Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'gsd1c5qt',
#      'authors': 'Householder, Hilary M.; Cassmann, Eric D.; White, Robin; Fales-Williams, Amanda; Viall, Austin K; Zaffarano, Bianca A.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC7106172.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106172/',
#      'doi': '10.1053/j.jepm.2018.10.006',
#      'host': 'kaggle-task',
#      'message': 'gsd1c5qt,,PMC,Paraplegia in a Domestic Ferret (Mustela Putorius Furo) Secondary to Metastatic Adrenocortical Carcinoma with Myxoid Differentiation,10.1053/j.jepm.2018.10.006,PMC7106172,,no-cc,"Neurologic disease is a common presentation of domestic ferrets (Mustela putorius furo) with infectious, neoplastic, and traumatic etiologies documented. Adrenocortical neoplasia is also well documented in domestic ferrets, with metastatic lesions rarely described. This case report describes an abnormal presentation of adrenocortical adenocarcinoma with myxoid differentiation and subsequent metastasis to the spinal cord and vertebral bodies, resulting in hind limb paraplegia in an adult spayed female ferret.",2018-11-20,"Householder, Hilary M.; Cassmann, Eric D.; White, Robin; Fales-Williams, Amanda; Viall, Austin K; Zaffarano, Bianca A.",J Exot Pet Med,,,,,document_parses/pmc_json/PMC7106172.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106172/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7106172',
#      'abstract': 'Neurologic disease is a common presentation of domestic ferrets (Mustela putorius furo) with infectious, neoplastic, and traumatic etiologies documented. Adrenocortical neoplasia is also well documented in domestic ferrets, with metastatic lesions rarely described. This case report describes an abnormal presentation of adrenocortical adenocarcinoma with myxoid differentiation and subsequent metastasis to the spinal cord and vertebral bodies, resulting in hind limb paraplegia in an adult spayed female ferret.',
#      'publish_time': '2018-11-20',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'XWUN-XMBkX4i4bZkrqQK',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'Systemic Infection Due to Candida parapsilosis in a Domestic Ferret (Mustela putorius furo)',
#      '@timestamp': '2020-08-16T20:54:48.918Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'wzp38kzr',
#      'authors': 'Mancinelli, Elisabetta; Meredith, Anna L.; Stidworthy, Mark F.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC7106228.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106228/',
#      'doi': '10.1053/j.jepm.2013.11.013',
#      'host': 'kaggle-task',
#      'message': 'wzp38kzr,,PMC,Systemic Infection Due to Candida parapsilosis in a Domestic Ferret (Mustela putorius furo),10.1053/j.jepm.2013.11.013,PMC7106228,,no-cc,"An 18-month-old castrated male ferret (Mustela putorius furo) was presented to the veterinary hospital for acute collapse but died despite initiation of emergency treatment. The body was submitted for a complete postmortem examination. The pathologist determined the ferret was suffering from severe necrotizing encephalitis, necrogranulomatous mediastinal lymphadenitis, and ulcerative dermatitis attributable to systemic Candida parapsilosis. This is the first report of systemic Candida parapsilosis in a ferret.",2013-12-01,"Mancinelli, Elisabetta; Meredith, Anna L.; Stidworthy, Mark F.",J Exot Pet Med,,,,,document_parses/pmc_json/PMC7106228.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106228/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7106228',
#      'abstract': 'An 18-month-old castrated male ferret (Mustela putorius furo) was presented to the veterinary hospital for acute collapse but died despite initiation of emergency treatment. The body was submitted for a complete postmortem examination. The pathologist determined the ferret was suffering from severe necrotizing encephalitis, necrogranulomatous mediastinal lymphadenitis, and ulcerative dermatitis attributable to systemic Candida parapsilosis. This is the first report of systemic Candida parapsilosis in a ferret.',
#      'publish_time': '2013-12-01',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'XmUN-XMBkX4i4bZkrqQK',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'Current Approach to Rodents as Patients',
#      '@timestamp': '2020-08-16T20:54:48.918Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'cdjd41nk',
#      'authors': 'Tamura, Yoko',
#      'pmc_json_files': 'document_parses/pmc_json/PMC7106322.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106322/',
#      'doi': '10.1053/j.jepm.2010.01.014',
#      'host': 'kaggle-task',
#      'message': 'cdjd41nk,,PMC,Current Approach to Rodents as Patients,10.1053/j.jepm.2010.01.014,PMC7106322,,no-cc,"Rodent species are routinely presented to veterinary hospitals for wellness checks and different illnesses. When rodents are presented to the veterinarian for diagnosis and treatment, they deserve the same thorough approach that any other domestic species receives. The purpose of this article is to provide readers a review of the current information regarding examination, diagnosis, and treatment of some of the most common conditions for which rodent patients are presented. This article will cover 5 of the most common rodent species presented to veterinarians: guinea pigs, chinchillas, rats, mice, and hamsters.",2010-05-05,"Tamura, Yoko",J Exot Pet Med,,,,,document_parses/pmc_json/PMC7106322.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106322/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7106322',
#      'abstract': 'Rodent species are routinely presented to veterinary hospitals for wellness checks and different illnesses. When rodents are presented to the veterinarian for diagnosis and treatment, they deserve the same thorough approach that any other domestic species receives. The purpose of this article is to provide readers a review of the current information regarding examination, diagnosis, and treatment of some of the most common conditions for which rodent patients are presented. This article will cover 5 of the most common rodent species presented to veterinarians: guinea pigs, chinchillas, rats, mice, and hamsters.',
#      'publish_time': '2010-05-05',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'sWUN-XMBkX4i4bZk0LM4',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'Avian & Exotic News',
#      '@timestamp': '2020-08-16T20:54:57.919Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'wz3porkn',
#      'authors': 'Orcutt, Connie',
#      'pmc_json_files': None,
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7129310/',
#      'doi': '10.1053/j.jepm.2016.03.016',
#      'host': 'kaggle-task',
#      'message': 'wz3porkn,,PMC,Avian & Exotic News,10.1053/j.jepm.2016.03.016,PMC7129310,,no-cc,,2016-05-21,"Orcutt, Connie",J Exot Pet Med,,,,,,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7129310/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7129310',
#      'abstract': None,
#      'publish_time': '2016-05-21',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'wGUN-XMBkX4i4bZk0bNW',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'Diagnostic Challenge',
#      '@timestamp': '2020-08-16T20:54:58.142Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'ycdo72np',
#      'authors': "Shanaman, Miriam M.; Mitchell, Mark A.; Haskins, Samantha; Welle, Ken; Demeter, Zoltan; Hsiao, Shih-Hsuan; Murrell-Ritter, Sandra; O'Brien, Robert T.",
#      'pmc_json_files': 'document_parses/pmc_json/PMC7129360.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7129360/',
#      'doi': '10.1053/j.jepm.2012.06.001',
#      'host': 'kaggle-task',
#      'message': 'ycdo72np,,PMC,Diagnostic Challenge,10.1053/j.jepm.2012.06.001,PMC7129360,,no-cc,,2012-07-30,"Shanaman, Miriam M.; Mitchell, Mark A.; Haskins, Samantha; Welle, Ken; Demeter, Zoltan; Hsiao, Shih-Hsuan; Murrell-Ritter, Sandra; O\'Brien, Robert T.",J Exot Pet Med,,,,,document_parses/pmc_json/PMC7129360.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7129360/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7129360',
#      'abstract': None,
#      'publish_time': '2012-07-30',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': '0mUN-XMBkX4i4bZk6sUi',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '851407a5f7f46dfdf332ac8f023c14c130a444f2',
#      'title': 'Equipment for Exotic Mammal and Reptile Diagnostics and Surgery',
#      '@timestamp': '2020-08-16T20:55:04.732Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'wg7hew1b',
#      'authors': 'Lennox, Angela M.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC7185823.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7185823/',
#      'doi': '10.1053/j.jepm.2006.02.005',
#      'host': 'kaggle-task',
#      'message': 'wg7hew1b,851407a5f7f46dfdf332ac8f023c14c130a444f2,PMC,Equipment for Exotic Mammal and Reptile Diagnostics and Surgery,10.1053/j.jepm.2006.02.005,PMC7185823,,no-cc,"The practice of veterinary medicine is facilitated by appropriate equipment, and exotic pet medicine is no exception. Exotic practitioners use standard or modified veterinary and human equipment, and now even enjoy the benefit of specialized products manufactured specifically for exotic pet practice.",2006-06-29,"Lennox, Angela M.",J Exot Pet Med,,,,document_parses/pdf_json/851407a5f7f46dfdf332ac8f023c14c130a444f2.json,document_parses/pmc_json/PMC7185823.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7185823/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7185823',
#      'abstract': 'The practice of veterinary medicine is facilitated by appropriate equipment, and exotic pet medicine is no exception. Exotic practitioners use standard or modified veterinary and human equipment, and now even enjoy the benefit of specialized products manufactured specifically for exotic pet practice.',
#      'publish_time': '2006-06-29',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': 'document_parses/pdf_json/851407a5f7f46dfdf332ac8f023c14c130a444f2.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': '02UN-XMBkX4i4bZk6sUi',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '050db25e81fca51e79421c81ebc288f0a514011b',
#      'title': 'Congenital Peripheral Vestibular Syndrome in a Domestic Ferret (Mustela putorius furo)',
#      '@timestamp': '2020-08-16T20:55:04.732Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'xj6245hn',
#      'authors': 'Moya, Alfonso; Mínguez, Juan J.; Martorell, Jaime; Gallinato, María J.; Recio, Alfredo',
#      'pmc_json_files': 'document_parses/pmc_json/PMC7185825.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7185825/',
#      'doi': '10.1053/j.jepm.2014.06.006',
#      'host': 'kaggle-task',
#      'message': 'xj6245hn,050db25e81fca51e79421c81ebc288f0a514011b,PMC,Congenital Peripheral Vestibular Syndrome in a Domestic Ferret (Mustela putorius furo),10.1053/j.jepm.2014.06.006,PMC7185825,,no-cc,"A 3-month-old intact female ferret (Mustela putorius furo) was presented with a 2-month history of ataxia. On physical examination, the ferret had difficulty standing upright. During the neurologic examination, the patient had a left head tilt and positional strabismus, circled to the left, and was ataxic. Results of the complete blood count were consistent with a mild normocytic normochromic anemia. Initial treatment was supportive. Magnetic resonance imaging was performed and revealed an asymmetry of the inner ears. A brainstem auditory evoked response test was also performed. History, clinical signs, and diagnostic test results indicated that the ferret was suffering from congenital peripheral vestibular syndrome and left-sided deafness. Congenital disease should be considered in the differential diagnosis of young ferrets with peripheral vestibular syndrome. Supportive care and physiotherapy can improve balance and motor function, leading to an acceptable quality of life.",2014-06-05,"Moya, Alfonso; Mínguez, Juan J.; Martorell, Jaime; Gallinato, María J.; Recio, Alfredo",J Exot Pet Med,,,,document_parses/pdf_json/050db25e81fca51e79421c81ebc288f0a514011b.json,document_parses/pmc_json/PMC7185825.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7185825/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7185825',
#      'abstract': 'A 3-month-old intact female ferret (Mustela putorius furo) was presented with a 2-month history of ataxia. On physical examination, the ferret had difficulty standing upright. During the neurologic examination, the patient had a left head tilt and positional strabismus, circled to the left, and was ataxic. Results of the complete blood count were consistent with a mild normocytic normochromic anemia. Initial treatment was supportive. Magnetic resonance imaging was performed and revealed an asymmetry of the inner ears. A brainstem auditory evoked response test was also performed. History, clinical signs, and diagnostic test results indicated that the ferret was suffering from congenital peripheral vestibular syndrome and left-sided deafness. Congenital disease should be considered in the differential diagnosis of young ferrets with peripheral vestibular syndrome. Supportive care and physiotherapy can improve balance and motor function, leading to an acceptable quality of life.',
#      'publish_time': '2014-06-05',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': 'document_parses/pdf_json/050db25e81fca51e79421c81ebc288f0a514011b.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'YWUN-XMBkX4i4bZk981j',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': None,
#      'title': 'July 2020 - Avian & Exotic News',
#      '@timestamp': '2020-08-16T20:55:07.763Z',
#      's2_id': None,
#      'pubmed_id': None,
#      'cord_uid': 'i1un68gg',
#      'authors': None,
#      'pmc_json_files': None,
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7272167/',
#      'doi': '10.1053/j.jepm.2020.05.003',
#      'host': 'kaggle-task',
#      'message': 'i1un68gg,,PMC,July 2020 - Avian & Exotic News,10.1053/j.jepm.2020.05.003,PMC7272167,,no-cc,,2020-06-04,,J Exot Pet Med,,,,,,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7272167/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC7272167',
#      'abstract': None,
#      'publish_time': '2020-06-04',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'KmcS-XMBkX4i4bZk0fU4',
#     '_score': 20.319862,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'Elsevier; Medline; PMC',
#      'sha': None,
#      'title': 'JEPM April 2020 – Avian & Exotic News',
#      '@timestamp': '2020-08-16T21:00:25.637Z',
#      's2_id': '215550924',
#      'pubmed_id': '32292309',
#      'cord_uid': '18clgess',
#      'authors': None,
#      'pmc_json_files': None,
#      'url': 'https://www.sciencedirect.com/science/article/pii/S1557506320300343; https://doi.org/10.1053/j.jepm.2020.03.001; https://api.elsevier.com/content/article/pii/S1557506320300343; https://www.ncbi.nlm.nih.gov/pubmed/32292309/',
#      'doi': '10.1053/j.jepm.2020.03.001',
#      'host': 'kaggle-task',
#      'message': '18clgess,,Elsevier; Medline; PMC,JEPM April 2020 – Avian & Exotic News,10.1053/j.jepm.2020.03.001,PMC7152929,32292309,els-covid,,2020-04-10,,J Exot Pet Med,,,,,,https://www.sciencedirect.com/science/article/pii/S1557506320300343; https://doi.org/10.1053/j.jepm.2020.03.001; https://api.elsevier.com/content/article/pii/S1557506320300343; https://www.ncbi.nlm.nih.gov/pubmed/32292309/,215550924\r',
#      'license': 'els-covid',
#      'pmcid': 'PMC7152929',
#      'abstract': None,
#      'publish_time': '2020-04-10',
#      'journal': 'J Exot Pet Med',
#      'pdf_json_files': None,
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}}]}}

# %%
source = es.search(index = "metafile",body = {
            "query": { 
                "bool": { 
                    "must": [
                        { "match": {'source_x': 'PMC'}}
                  ],
                }
              }
            })

source
# Out:
# {'took': 6,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 0.9300287,
#   'hits': [{'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'TWUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '373811bcfe3a46dc6d49b2a1725f1dde8a59e8a9',
#      'title': 'Spatial dynamics of the 1918 influenza pandemic in England, Wales and the United States',
#      '@timestamp': '2020-08-16T20:54:02.070Z',
#      's2_id': None,
#      'pubmed_id': '20573630',
#      'cord_uid': 'pixbry0c',
#      'authors': 'Eggo, Rosalind M.; Cauchemez, Simon; Ferguson, Neil M.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3033019.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3033019/',
#      'doi': '10.1098/rsif.2010.0216',
#      'host': 'kaggle-task',
#      'message': 'pixbry0c,373811bcfe3a46dc6d49b2a1725f1dde8a59e8a9,PMC,"Spatial dynamics of the 1918 influenza pandemic in England, Wales and the United States",10.1098/rsif.2010.0216,PMC3033019,20573630,cc-by,"There is still limited understanding of key determinants of spatial spread of influenza. The 1918 pandemic provides an opportunity to elucidate spatial determinants of spread on a large scale. To better characterize the spread of the 1918 major wave, we fitted a range of city-to-city transmission models to mortality data collected for 246 population centres in England and Wales and 47 cities in the US. Using a gravity model for city-to-city contacts, we explored the effect of population size and distance on the spread of disease and tested assumptions regarding density dependence in connectivity between cities. We employed Bayesian Markov Chain Monte Carlo methods to estimate parameters of the model for population, infectivity, distance and density dependence. We inferred the most likely transmission trees for both countries. For England and Wales, a model that estimated the degree of density dependence in connectivity between cities was preferable by deviance information criterion comparison. Early in the major wave, long distance infective interactions predominated, with local infection events more likely as the epidemic became widespread. For the US, with fewer more widely dispersed cities, statistical power was lacking to estimate population size dependence or the degree of density dependence, with the preferred model depending on distance only. We find that parameters estimated from the England and Wales dataset can be applied to the US data with no likelihood penalty.",2011-02-06,"Eggo, Rosalind M.; Cauchemez, Simon; Ferguson, Neil M.",J R Soc Interface,,,,document_parses/pdf_json/373811bcfe3a46dc6d49b2a1725f1dde8a59e8a9.json,document_parses/pmc_json/PMC3033019.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3033019/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3033019',
#      'abstract': 'There is still limited understanding of key determinants of spatial spread of influenza. The 1918 pandemic provides an opportunity to elucidate spatial determinants of spread on a large scale. To better characterize the spread of the 1918 major wave, we fitted a range of city-to-city transmission models to mortality data collected for 246 population centres in England and Wales and 47 cities in the US. Using a gravity model for city-to-city contacts, we explored the effect of population size and distance on the spread of disease and tested assumptions regarding density dependence in connectivity between cities. We employed Bayesian Markov Chain Monte Carlo methods to estimate parameters of the model for population, infectivity, distance and density dependence. We inferred the most likely transmission trees for both countries. For England and Wales, a model that estimated the degree of density dependence in connectivity between cities was preferable by deviance information criterion comparison. Early in the major wave, long distance infective interactions predominated, with local infection events more likely as the epidemic became widespread. For the US, with fewer more widely dispersed cities, statistical power was lacking to estimate population size dependence or the degree of density dependence, with the preferred model depending on distance only. We find that parameters estimated from the England and Wales dataset can be applied to the US data with no likelihood penalty.',
#      'publish_time': '2011-02-06',
#      'journal': 'J R Soc Interface',
#      'pdf_json_files': 'document_parses/pdf_json/373811bcfe3a46dc6d49b2a1725f1dde8a59e8a9.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'TmUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': 'b708da1945a7a42cd61526e043d527592d4d9518',
#      'title': 'Charge-Surrounded Pockets and Electrostatic Interactions with Small Ions Modulate the Activity of Retroviral Fusion Proteins',
#      '@timestamp': '2020-08-16T20:54:02.070Z',
#      's2_id': None,
#      'pubmed_id': '21304939',
#      'cord_uid': 'wk2u2a9w',
#      'authors': 'Lamb, Daniel; Schüttelkopf, Alexander W.; van Aalten, Daan M. F.; Brighty, David W.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3033372.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3033372/',
#      'doi': '10.1371/journal.ppat.1001268',
#      'host': 'kaggle-task',
#      'message': 'wk2u2a9w,b708da1945a7a42cd61526e043d527592d4d9518,PMC,Charge-Surrounded Pockets and Electrostatic Interactions with Small Ions Modulate the Activity of Retroviral Fusion Proteins,10.1371/journal.ppat.1001268,PMC3033372,21304939,cc-by,"Refolding of viral class-1 membrane fusion proteins from a native state to a trimer-of-hairpins structure promotes entry of viruses into cells. Here we present the structure of the bovine leukaemia virus transmembrane glycoprotein (TM) and identify a group of asparagine residues at the membrane-distal end of the trimer-of-hairpins that is strikingly conserved among divergent viruses. These asparagines are not essential for surface display of pre-fusogenic envelope. Instead, substitution of these residues dramatically disrupts membrane fusion. Our data indicate that, through electrostatic interactions with a chloride ion, the asparagine residues promote assembly and profoundly stabilize the fusion-active structures that are required for viral envelope-mediated membrane fusion. Moreover, the BLV TM structure also reveals a charge-surrounded hydrophobic pocket on the central coiled coil and interactions with basic residues that cluster around this pocket are critical to membrane fusion and form a target for peptide inhibitors of envelope function. Charge-surrounded pockets and electrostatic interactions with small ions are common among class-1 fusion proteins, suggesting that small molecules that specifically target such motifs should prevent assembly of the trimer-of-hairpins and be of value as therapeutic inhibitors of viral entry.",2011-02-03,"Lamb, Daniel; Schüttelkopf, Alexander W.; van Aalten, Daan M. F.; Brighty, David W.",PLoS Pathog,,,,document_parses/pdf_json/b708da1945a7a42cd61526e043d527592d4d9518.json,document_parses/pmc_json/PMC3033372.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3033372/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3033372',
#      'abstract': 'Refolding of viral class-1 membrane fusion proteins from a native state to a trimer-of-hairpins structure promotes entry of viruses into cells. Here we present the structure of the bovine leukaemia virus transmembrane glycoprotein (TM) and identify a group of asparagine residues at the membrane-distal end of the trimer-of-hairpins that is strikingly conserved among divergent viruses. These asparagines are not essential for surface display of pre-fusogenic envelope. Instead, substitution of these residues dramatically disrupts membrane fusion. Our data indicate that, through electrostatic interactions with a chloride ion, the asparagine residues promote assembly and profoundly stabilize the fusion-active structures that are required for viral envelope-mediated membrane fusion. Moreover, the BLV TM structure also reveals a charge-surrounded hydrophobic pocket on the central coiled coil and interactions with basic residues that cluster around this pocket are critical to membrane fusion and form a target for peptide inhibitors of envelope function. Charge-surrounded pockets and electrostatic interactions with small ions are common among class-1 fusion proteins, suggesting that small molecules that specifically target such motifs should prevent assembly of the trimer-of-hairpins and be of value as therapeutic inhibitors of viral entry.',
#      'publish_time': '2011-02-03',
#      'journal': 'PLoS Pathog',
#      'pdf_json_files': 'document_parses/pdf_json/b708da1945a7a42cd61526e043d527592d4d9518.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'T2UN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': 'da749301de23f38cbef2e9c54a50d2e7e646f691',
#      'title': 'Tracheostomy and mechanical ventilation weaning in children affected by respiratory virus according to a weaning protocol in a pediatric intensive care unit in Argentina: an observational restrospective trial',
#      '@timestamp': '2020-08-16T20:54:02.070Z',
#      's2_id': None,
#      'pubmed_id': '21244710',
#      'cord_uid': 'x7dqe8qa',
#      'authors': 'Caprotta, Gustavo; Gonzalez Crotti, Patricia; Frydman, Judith',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3035030.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3035030/',
#      'doi': '10.1186/1824-7288-37-5',
#      'host': 'kaggle-task',
#      'message': 'x7dqe8qa,da749301de23f38cbef2e9c54a50d2e7e646f691,PMC,Tracheostomy and mechanical ventilation weaning in children affected by respiratory virus according to a weaning protocol in a pediatric intensive care unit in Argentina: an observational restrospective trial,10.1186/1824-7288-37-5,PMC3035030,21244710,cc-by,"We describe difficult weaning after prolonged mechanical ventilation in three tracheostomized children affected by respiratory virus infection. Although the spontaneous breathing trials were successful, the patients failed all extubations. Therefore a tracheostomy was performed and the weaning plan was begun. The strategy for weaning was the decrease of ventilation support combining pressure control ventilation (PCV) with increasing periods of continuous positive airway pressure + pressure support ventilation (CPAP + PSV) and then CPAP + PSV with increasing intervals of T-piece. They presented acute respiratory distress syndrome on admission with high requirements of mechanical ventilation (MV). Intervening factors in the capabilities and loads of the respiratory system were considered and optimized. The average MV time was 69 days and weaning time 31 days. We report satisfactory results within the context of a directed weaning protocol.",2011-01-19,"Caprotta, Gustavo; Gonzalez Crotti, Patricia; Frydman, Judith",Ital J Pediatr,,,,document_parses/pdf_json/da749301de23f38cbef2e9c54a50d2e7e646f691.json,document_parses/pmc_json/PMC3035030.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3035030/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3035030',
#      'abstract': 'We describe difficult weaning after prolonged mechanical ventilation in three tracheostomized children affected by respiratory virus infection. Although the spontaneous breathing trials were successful, the patients failed all extubations. Therefore a tracheostomy was performed and the weaning plan was begun. The strategy for weaning was the decrease of ventilation support combining pressure control ventilation (PCV) with increasing periods of continuous positive airway pressure + pressure support ventilation (CPAP + PSV) and then CPAP + PSV with increasing intervals of T-piece. They presented acute respiratory distress syndrome on admission with high requirements of mechanical ventilation (MV). Intervening factors in the capabilities and loads of the respiratory system were considered and optimized. The average MV time was 69 days and weaning time 31 days. We report satisfactory results within the context of a directed weaning protocol.',
#      'publish_time': '2011-01-19',
#      'journal': 'Ital J Pediatr',
#      'pdf_json_files': 'document_parses/pdf_json/da749301de23f38cbef2e9c54a50d2e7e646f691.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'UGUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '54e77bff1912076bccf12a6b099e48a59f634d5f; 21337e54a7d02b12aea5f5835648d69aef32701e',
#      'title': 'The activity of the HIV-1 IRES is stimulated by oxidative stress and controlled by a negative regulatory element',
#      '@timestamp': '2020-08-16T20:54:02.071Z',
#      's2_id': None,
#      'pubmed_id': '20935056',
#      'cord_uid': 'qtn3ukf4',
#      'authors': 'Gendron, Karine; Ferbeyre, Gerardo; Heveker, Nikolaus; Brakier-Gingras, Léa',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3035469.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3035469/',
#      'doi': '10.1093/nar/gkq885',
#      'host': 'kaggle-task',
#      'message': 'qtn3ukf4,54e77bff1912076bccf12a6b099e48a59f634d5f; 21337e54a7d02b12aea5f5835648d69aef32701e,PMC,The activity of the HIV-1 IRES is stimulated by oxidative stress and controlled by a negative regulatory element,10.1093/nar/gkq885,PMC3035469,20935056,cc-by-nc,"Initiation of translation of the full-length messenger RNA of HIV-1, which generates the viral structural proteins and enzymes, is cap-dependent but can also use an internal ribosome entry site (IRES) located in the 5′ untranslated region. Our aim was to define, through a mutational analysis, regions of HIV-1 IRES that are important for its activity. A dual-luciferase reporter construct where the Renilla luciferase (Rluc) translation is cap-dependent while the firefly luciferase (Fluc) translation depends on HIV-1 IRES was used. The Fluc/Rluc ratio was measured in lysates of Jurkat T cells transfected with the dual-luciferase plasmid bearing either the wild-type or a mutated IRES. Deletions or mutations in three regions decreased the IRES activity but deletion or mutations of a stem-loop preceding the primer binding site increased the IRES activity. The wild-type IRES activity, but not that of an IRES with a mutated stem-loop, was increased when cells were treated with agents that induce oxidative stress. Such stress is known to be caused by HIV-1 infection and we propose that this stem-loop is involved in a switch that stimulates the IRES activity in cells infected with HIV-1, supporting the suggestion that the IRES activity is up-regulated in the course of HIV-1 replication cycle.",2010-10-08,"Gendron, Karine; Ferbeyre, Gerardo; Heveker, Nikolaus; Brakier-Gingras, Léa",Nucleic Acids Res,,,,document_parses/pdf_json/54e77bff1912076bccf12a6b099e48a59f634d5f.json; document_parses/pdf_json/21337e54a7d02b12aea5f5835648d69aef32701e.json,document_parses/pmc_json/PMC3035469.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3035469/,\r',
#      'license': 'cc-by-nc',
#      'pmcid': 'PMC3035469',
#      'abstract': 'Initiation of translation of the full-length messenger RNA of HIV-1, which generates the viral structural proteins and enzymes, is cap-dependent but can also use an internal ribosome entry site (IRES) located in the 5′ untranslated region. Our aim was to define, through a mutational analysis, regions of HIV-1 IRES that are important for its activity. A dual-luciferase reporter construct where the Renilla luciferase (Rluc) translation is cap-dependent while the firefly luciferase (Fluc) translation depends on HIV-1 IRES was used. The Fluc/Rluc ratio was measured in lysates of Jurkat T cells transfected with the dual-luciferase plasmid bearing either the wild-type or a mutated IRES. Deletions or mutations in three regions decreased the IRES activity but deletion or mutations of a stem-loop preceding the primer binding site increased the IRES activity. The wild-type IRES activity, but not that of an IRES with a mutated stem-loop, was increased when cells were treated with agents that induce oxidative stress. Such stress is known to be caused by HIV-1 infection and we propose that this stem-loop is involved in a switch that stimulates the IRES activity in cells infected with HIV-1, supporting the suggestion that the IRES activity is up-regulated in the course of HIV-1 replication cycle.',
#      'publish_time': '2010-10-08',
#      'journal': 'Nucleic Acids Res',
#      'pdf_json_files': 'document_parses/pdf_json/54e77bff1912076bccf12a6b099e48a59f634d5f.json; document_parses/pdf_json/21337e54a7d02b12aea5f5835648d69aef32701e.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'UWUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '9e0f14131900d5136cabf11f654a5cbb9d88ad48',
#      'title': 'Further Characterisation of the Translational Termination-Reinitiation Signal of the Influenza B Virus Segment 7 RNA',
#      '@timestamp': '2020-08-16T20:54:02.071Z',
#      's2_id': None,
#      'pubmed_id': '21347434',
#      'cord_uid': 'ee7q7jhv',
#      'authors': 'Powell, Michael L.; Leigh, Kendra E.; Pöyry, Tuija A. A.; Jackson, Richard J.; Brown, T. David K.; Brierley, Ian',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3035654.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3035654/',
#      'doi': '10.1371/journal.pone.0016822',
#      'host': 'kaggle-task',
#      'message': 'ee7q7jhv,9e0f14131900d5136cabf11f654a5cbb9d88ad48,PMC,Further Characterisation of the Translational Termination-Reinitiation Signal of the Influenza B Virus Segment 7 RNA,10.1371/journal.pone.0016822,PMC3035654,21347434,cc-by,"Termination-dependent reinitiation is used to co-ordinately regulate expression of the M1 and BM2 open-reading frames (ORFs) of the dicistronic influenza B segment 7 RNA. The start codon of the BM2 ORF overlaps the stop codon of the M1 ORF in the pentanucleotide UAA UG and ∼10% of ribosomes terminating at the M1 stop codon reinitiate translation at the overlapping AUG. BM2 synthesis requires the presence of, and translation through, 45 nt of RNA immediately upstream of the UAA UG, known as the ‘termination upstream ribosome binding site’ (TURBS). This region may tether ribosomal 40S subunits to the mRNA following termination and a short region of the TURBS, motif 1, with complementarity to helix 26 of 18S rRNA has been implicated in this process. Here, we provide further evidence for a direct interaction between mRNA and rRNA using antisense oligonucleotide targeting and functional analysis in yeast cells. The TURBS also binds initiation factor eIF3 and we show here that this protein stimulates reinitiation from both wild-type and defective TURBS when added exogenously, perhaps by stabilising ribosome-mRNA interactions. Further, we show that the position of the TURBS with respect to the UAA UG overlap is crucial, and that termination too far downstream of the 18S complementary sequence inhibits the process, probably due to reduced 40S tethering. However, in reporter mRNAs where the restart codon alone is moved downstream, termination-reinitiation is inhibited but not abolished, thus the site of reinitiation is somewhat flexible. Reinitiation on distant AUGs is not inhibited in eIF4G-depleted RRL, suggesting that the tethered 40S subunit can move some distance without a requirement for linear scanning.",2011-02-08,"Powell, Michael L.; Leigh, Kendra E.; Pöyry, Tuija A. A.; Jackson, Richard J.; Brown, T. David K.; Brierley, Ian",PLoS One,,,,document_parses/pdf_json/9e0f14131900d5136cabf11f654a5cbb9d88ad48.json,document_parses/pmc_json/PMC3035654.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3035654/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3035654',
#      'abstract': 'Termination-dependent reinitiation is used to co-ordinately regulate expression of the M1 and BM2 open-reading frames (ORFs) of the dicistronic influenza B segment 7 RNA. The start codon of the BM2 ORF overlaps the stop codon of the M1 ORF in the pentanucleotide UAA UG and ∼10% of ribosomes terminating at the M1 stop codon reinitiate translation at the overlapping AUG. BM2 synthesis requires the presence of, and translation through, 45 nt of RNA immediately upstream of the UAA UG, known as the ‘termination upstream ribosome binding site’ (TURBS). This region may tether ribosomal 40S subunits to the mRNA following termination and a short region of the TURBS, motif 1, with complementarity to helix 26 of 18S rRNA has been implicated in this process. Here, we provide further evidence for a direct interaction between mRNA and rRNA using antisense oligonucleotide targeting and functional analysis in yeast cells. The TURBS also binds initiation factor eIF3 and we show here that this protein stimulates reinitiation from both wild-type and defective TURBS when added exogenously, perhaps by stabilising ribosome-mRNA interactions. Further, we show that the position of the TURBS with respect to the UAA UG overlap is crucial, and that termination too far downstream of the 18S complementary sequence inhibits the process, probably due to reduced 40S tethering. However, in reporter mRNAs where the restart codon alone is moved downstream, termination-reinitiation is inhibited but not abolished, thus the site of reinitiation is somewhat flexible. Reinitiation on distant AUGs is not inhibited in eIF4G-depleted RRL, suggesting that the tethered 40S subunit can move some distance without a requirement for linear scanning.',
#      'publish_time': '2011-02-08',
#      'journal': 'PLoS One',
#      'pdf_json_files': 'document_parses/pdf_json/9e0f14131900d5136cabf11f654a5cbb9d88ad48.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'UmUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '49ef14fbeee682057ed14674f623ca36c6d954cc',
#      'title': 'RNA and DNA Bacteriophages as Molecular Diagnosis Controls in Clinical Virology: A Comprehensive Study of More than 45,000 Routine PCR Tests',
#      '@timestamp': '2020-08-16T20:54:02.073Z',
#      's2_id': None,
#      'pubmed_id': '21347398',
#      'cord_uid': '8ctsa9sd',
#      'authors': 'Ninove, Laetitia; Nougairede, Antoine; Gazin, Celine; Thirion, Laurence; Delogu, Ilenia; Zandotti, Christine; Charrel, Remi N.; De Lamballerie, Xavier',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3036576.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3036576/',
#      'doi': '10.1371/journal.pone.0016142',
#      'host': 'kaggle-task',
#      'message': '8ctsa9sd,49ef14fbeee682057ed14674f623ca36c6d954cc,PMC,"RNA and DNA Bacteriophages as Molecular Diagnosis Controls in Clinical Virology: A Comprehensive Study of More than 45,000 Routine PCR Tests",10.1371/journal.pone.0016142,PMC3036576,21347398,cc-by,"Real-time PCR techniques are now commonly used for the detection of viral genomes in various human specimens and require for validation both external and internal controls (ECs and ICs). In particular, ICs added to clinical samples are necessary to monitor the extraction, reverse transcription, and amplification steps in order to detect false-negative results resulting from PCR-inhibition or errors in the technical procedure. Here, we performed a large scale evaluation of the use of bacteriophages as ICs in routine molecular diagnosis. This allowed to propose simple standardized procedures (i) to design specific ECs for both DNA and RNA viruses and (ii) to use T4 (DNA) or MS2 (RNA) phages as ICs in routine diagnosis. Various technical formats for using phages as ICs were optimised and validated. Subsequently, T4 and MS2 ICs were evaluated in routine real-time PCR or RT-PCR virological diagnostic tests, using a series of 8,950 clinical samples (representing 36 distinct specimen types) sent to our laboratory for the detection of a variety of DNA and RNA viruses. The frequency of inefficient detection of ICs was analyzed according to the nature of the sample. Inhibitors of enzymatic reactions were detected at high frequency in specific sample types such as heparinized blood and bone marrow (>70%), broncho-alveolar liquid (41%) and stools (36%). The use of T4 and MS2 phages as ICs proved to be cost-effective, flexible and adaptable to various technical procedures of real-time PCR detection in virology. It represents a valuable strategy for enhancing the quality of routine molecular diagnosis in laboratories that use in-house designed diagnostic systems, which can conveniently be associated to the use of specific synthetic ECs. The high rate of inhibitors observed in a variety of specimen types should stimulate the elaboration of improved technical protocols for the extraction and amplification of nucleic acids.",2011-02-09,"Ninove, Laetitia; Nougairede, Antoine; Gazin, Celine; Thirion, Laurence; Delogu, Ilenia; Zandotti, Christine; Charrel, Remi N.; De Lamballerie, Xavier",PLoS One,,,,document_parses/pdf_json/49ef14fbeee682057ed14674f623ca36c6d954cc.json,document_parses/pmc_json/PMC3036576.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3036576/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3036576',
#      'abstract': 'Real-time PCR techniques are now commonly used for the detection of viral genomes in various human specimens and require for validation both external and internal controls (ECs and ICs). In particular, ICs added to clinical samples are necessary to monitor the extraction, reverse transcription, and amplification steps in order to detect false-negative results resulting from PCR-inhibition or errors in the technical procedure. Here, we performed a large scale evaluation of the use of bacteriophages as ICs in routine molecular diagnosis. This allowed to propose simple standardized procedures (i) to design specific ECs for both DNA and RNA viruses and (ii) to use T4 (DNA) or MS2 (RNA) phages as ICs in routine diagnosis. Various technical formats for using phages as ICs were optimised and validated. Subsequently, T4 and MS2 ICs were evaluated in routine real-time PCR or RT-PCR virological diagnostic tests, using a series of 8,950 clinical samples (representing 36 distinct specimen types) sent to our laboratory for the detection of a variety of DNA and RNA viruses. The frequency of inefficient detection of ICs was analyzed according to the nature of the sample. Inhibitors of enzymatic reactions were detected at high frequency in specific sample types such as heparinized blood and bone marrow (>70%), broncho-alveolar liquid (41%) and stools (36%). The use of T4 and MS2 phages as ICs proved to be cost-effective, flexible and adaptable to various technical procedures of real-time PCR detection in virology. It represents a valuable strategy for enhancing the quality of routine molecular diagnosis in laboratories that use in-house designed diagnostic systems, which can conveniently be associated to the use of specific synthetic ECs. The high rate of inhibitors observed in a variety of specimen types should stimulate the elaboration of improved technical protocols for the extraction and amplification of nucleic acids.',
#      'publish_time': '2011-02-09',
#      'journal': 'PLoS One',
#      'pdf_json_files': 'document_parses/pdf_json/49ef14fbeee682057ed14674f623ca36c6d954cc.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'U2UN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '61c544c0073ac03b02ec00b3f4319ff311eb642a',
#      'title': 'Pandemic H1N1 2009 influenza virus with the H275Y oseltamivir resistance neuraminidase mutation shows a small compromise in enzyme activity and viral fitness',
#      '@timestamp': '2020-08-16T20:54:02.073Z',
#      's2_id': None,
#      'pubmed_id': '21172786',
#      'cord_uid': 'zokd0uxp',
#      'authors': 'Brookes, Daniel W.; Miah, Shahajahan; Lackenby, Angie; Hartgroves, Lorian; Barclay, Wendy S.',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3037153.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3037153/',
#      'doi': '10.1093/jac/dkq486',
#      'host': 'kaggle-task',
#      'message': 'zokd0uxp,61c544c0073ac03b02ec00b3f4319ff311eb642a,PMC,Pandemic H1N1 2009 influenza virus with the H275Y oseltamivir resistance neuraminidase mutation shows a small compromise in enzyme activity and viral fitness,10.1093/jac/dkq486,PMC3037153,21172786,no-cc,"BACKGROUND: Resistance to the neuraminidase inhibitor oseltamivir can be conferred by a well-characterized mutation in the neuraminidase gene, H275Y. In human H1N1 viruses that circulated in the first years of the 21st century, this mutation carried a fitness cost and resistant viruses were rare. During the 2007–08 influenza season, oseltamivir-resistant viruses of H1N1 phenotype emerged and predominated. March 2009 saw the emergence of a novel H1N1 influenza pandemic. We examined whether the H275Y mutation affected neuraminidase enzyme activity or replication of the pandemic influenza virus. METHODS: Using reverse genetics we engineered the H275Y mutation into the neuraminidase of a 2009 pandemic H1N1 virus and assessed the ability of this enzyme to desialylate mono- and multivalent substrates. The growth kinetics of wild-type and mutant viruses were assessed in Madin–Darby canine kidney (MDCK) and fully differentiated human airway epithelial (HAE) cells. RESULTS: The presence of H275Y was associated with a 1.3-fold decrease in the affinity of the neuraminidase for a monovalent substrate and a 4-fold compromise in desialylation of multivalent substrate. This was associated with a fitness cost to viral replication in vitro, which only became apparent during competitive replication in the mucus-rich HAE culture system. CONCLUSIONS: The neuraminidase protein of pandemic influenza isolates tolerates the H275Y mutation and this mutation confers resistance to oseltamivir. However, unlike seasonal H1N1 viruses isolated since 2007, the mutation is not associated with any fitness advantage and thus is unlikely to predominate without further antigenic drift, compensating mutations or intense selection pressure.",2010-12-16,"Brookes, Daniel W.; Miah, Shahajahan; Lackenby, Angie; Hartgroves, Lorian; Barclay, Wendy S.",J Antimicrob Chemother,,,,document_parses/pdf_json/61c544c0073ac03b02ec00b3f4319ff311eb642a.json,document_parses/pmc_json/PMC3037153.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3037153/,\r',
#      'license': 'no-cc',
#      'pmcid': 'PMC3037153',
#      'abstract': 'BACKGROUND: Resistance to the neuraminidase inhibitor oseltamivir can be conferred by a well-characterized mutation in the neuraminidase gene, H275Y. In human H1N1 viruses that circulated in the first years of the 21st century, this mutation carried a fitness cost and resistant viruses were rare. During the 2007–08 influenza season, oseltamivir-resistant viruses of H1N1 phenotype emerged and predominated. March 2009 saw the emergence of a novel H1N1 influenza pandemic. We examined whether the H275Y mutation affected neuraminidase enzyme activity or replication of the pandemic influenza virus. METHODS: Using reverse genetics we engineered the H275Y mutation into the neuraminidase of a 2009 pandemic H1N1 virus and assessed the ability of this enzyme to desialylate mono- and multivalent substrates. The growth kinetics of wild-type and mutant viruses were assessed in Madin–Darby canine kidney (MDCK) and fully differentiated human airway epithelial (HAE) cells. RESULTS: The presence of H275Y was associated with a 1.3-fold decrease in the affinity of the neuraminidase for a monovalent substrate and a 4-fold compromise in desialylation of multivalent substrate. This was associated with a fitness cost to viral replication in vitro, which only became apparent during competitive replication in the mucus-rich HAE culture system. CONCLUSIONS: The neuraminidase protein of pandemic influenza isolates tolerates the H275Y mutation and this mutation confers resistance to oseltamivir. However, unlike seasonal H1N1 viruses isolated since 2007, the mutation is not associated with any fitness advantage and thus is unlikely to predominate without further antigenic drift, compensating mutations or intense selection pressure.',
#      'publish_time': '2010-12-16',
#      'journal': 'J Antimicrob Chemother',
#      'pdf_json_files': 'document_parses/pdf_json/61c544c0073ac03b02ec00b3f4319ff311eb642a.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'VGUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '960d26b871399621a1c32ff4b8459429893caf18',
#      'title': 'Ketamine inhibits tumor necrosis factor secretion by RAW264.7 murine macrophages stimulated with antibiotic-exposed strains of community-associated, methicillin-resistant Staphylococcus aureus',
#      '@timestamp': '2020-08-16T20:54:02.073Z',
#      's2_id': None,
#      'pubmed_id': '21266054',
#      'cord_uid': 'to4g9he9',
#      'authors': 'Spentzas, Thomas; Shapley, Rebekah KH; Aguirre, Carlos Acuna; Meals, Elizabeth; Lazar, Lauren; Rayburn, Mark S; Walker, Brett S; English, B Keith',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3037927.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3037927/',
#      'doi': '10.1186/1471-2172-12-11',
#      'host': 'kaggle-task',
#      'message': 'to4g9he9,960d26b871399621a1c32ff4b8459429893caf18,PMC,"Ketamine inhibits tumor necrosis factor secretion by RAW264.7 murine macrophages stimulated with antibiotic-exposed strains of community-associated, methicillin-resistant Staphylococcus aureus",10.1186/1471-2172-12-11,PMC3037927,21266054,cc-by,"BACKGROUND: Infections caused by community-associated strains of methicillin-resistant Staphylococcus aureus (CA-MRSA) are associated with a marked and prolonged host inflammatory response. In a sepsis simulation model, we tested whether the anesthetic ketamine inhibits the macrophage TNF response to antibiotic-exposed CA-MRSA bacteria via its antagonism of N-methyl-D-aspartate (NMDA) receptors. RAW264.7 cells were stimulated for 18 hrs with 10(5 )to 10(7 )CFU/mL inocula of either of two prototypical CA-MRSA isolates, USA300 strain LAC and USA400 strain MW2, in the presence of either vancomycin or daptomycin. One hour before bacterial stimulation, ketamine was added with or without MK-801 (dizocilpine, a chemically unrelated non-competitive NMDA receptor antagonist), APV (D-2-amino-5-phosphono-valerate, a competitive NMDA receptor antagonist), NMDA, or combinations of these agents. Supernatants were collected and assayed for TNF concentration by ELISA. RESULTS: RAW264.7 cells exposed to either LAC or MW2 in the presence of daptomycin secreted less TNF than in the presence of vancomycin. The addition of ketamine inhibited macrophage TNF secretion after stimulation with either of the CA-MRSA isolates (LAC, MW2) in the presence of either antibiotic. The NMDA inhibitors, MK-801 and APV, also suppressed macrophage TNF secretion after stimulation with either of the antibiotic-exposed CA-MRSA isolates, and the effect was not additive or synergistic with ketamine. The addition of NMDA substrate augmented TNF secretion in response to the CA-MRSA bacteria, and the addition of APV suppressed the effect of NMDA in a dose-dependent fashion. CONCLUSIONS: Ketamine inhibits TNF secretion by MRSA-stimulated RAW264.7 macrophages and the mechanism likely involves NMDA receptor antagonism. These findings may have therapeutic significance in MRSA sepsis.",2011-01-25,"Spentzas, Thomas; Shapley, Rebekah KH; Aguirre, Carlos Acuna; Meals, Elizabeth; Lazar, Lauren; Rayburn, Mark S; Walker, Brett S; English, B Keith",BMC Immunol,,,,document_parses/pdf_json/960d26b871399621a1c32ff4b8459429893caf18.json,document_parses/pmc_json/PMC3037927.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3037927/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3037927',
#      'abstract': 'BACKGROUND: Infections caused by community-associated strains of methicillin-resistant Staphylococcus aureus (CA-MRSA) are associated with a marked and prolonged host inflammatory response. In a sepsis simulation model, we tested whether the anesthetic ketamine inhibits the macrophage TNF response to antibiotic-exposed CA-MRSA bacteria via its antagonism of N-methyl-D-aspartate (NMDA) receptors. RAW264.7 cells were stimulated for 18 hrs with 10(5 )to 10(7 )CFU/mL inocula of either of two prototypical CA-MRSA isolates, USA300 strain LAC and USA400 strain MW2, in the presence of either vancomycin or daptomycin. One hour before bacterial stimulation, ketamine was added with or without MK-801 (dizocilpine, a chemically unrelated non-competitive NMDA receptor antagonist), APV (D-2-amino-5-phosphono-valerate, a competitive NMDA receptor antagonist), NMDA, or combinations of these agents. Supernatants were collected and assayed for TNF concentration by ELISA. RESULTS: RAW264.7 cells exposed to either LAC or MW2 in the presence of daptomycin secreted less TNF than in the presence of vancomycin. The addition of ketamine inhibited macrophage TNF secretion after stimulation with either of the CA-MRSA isolates (LAC, MW2) in the presence of either antibiotic. The NMDA inhibitors, MK-801 and APV, also suppressed macrophage TNF secretion after stimulation with either of the antibiotic-exposed CA-MRSA isolates, and the effect was not additive or synergistic with ketamine. The addition of NMDA substrate augmented TNF secretion in response to the CA-MRSA bacteria, and the addition of APV suppressed the effect of NMDA in a dose-dependent fashion. CONCLUSIONS: Ketamine inhibits TNF secretion by MRSA-stimulated RAW264.7 macrophages and the mechanism likely involves NMDA receptor antagonism. These findings may have therapeutic significance in MRSA sepsis.',
#      'publish_time': '2011-01-25',
#      'journal': 'BMC Immunol',
#      'pdf_json_files': 'document_parses/pdf_json/960d26b871399621a1c32ff4b8459429893caf18.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'VWUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '7b9e45133c8a6f6c48ec8c5f1f0c01ad0cd1d3ae',
#      'title': 'Avipoxviruses: infection biology and their use as vaccine vectors',
#      '@timestamp': '2020-08-16T20:54:02.073Z',
#      's2_id': None,
#      'pubmed_id': '21291547',
#      'cord_uid': 'ussnj6ux',
#      'authors': 'Weli, Simon C; Tryland, Morten',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3042955.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3042955/',
#      'doi': '10.1186/1743-422x-8-49',
#      'host': 'kaggle-task',
#      'message': 'ussnj6ux,7b9e45133c8a6f6c48ec8c5f1f0c01ad0cd1d3ae,PMC,Avipoxviruses: infection biology and their use as vaccine vectors,10.1186/1743-422x-8-49,PMC3042955,21291547,cc-by,"Avipoxviruses (APVs) belong to the Chordopoxvirinae subfamily of the Poxviridae family. APVs are distributed worldwide and cause disease in domestic, pet and wild birds of many species. APVs are transmitted by aerosols and biting insects, particularly mosquitoes and arthropods and are usually named after the bird species from which they were originally isolated. The virus species Fowlpox virus (FWPV) causes disease in poultry and associated mortality is usually low, but in flocks under stress (other diseases, high production) mortality can reach up to 50%. APVs are also major players in viral vaccine vector development for diseases in human and veterinary medicine. Abortive infection in mammalian cells (no production of progeny viruses) and their ability to accommodate multiple gene inserts are some of the characteristics that make APVs promising vaccine vectors. Although abortive infection in mammalian cells conceivably represents a major vaccine bio-safety advantage, molecular mechanisms restricting APVs to certain hosts are not yet fully understood. This review summarizes the current knowledge relating to APVs, including classification, morphogenesis, host-virus interactions, diagnostics and disease, and also highlights the use of APVs as recombinant vaccine vectors.",2011-02-03,"Weli, Simon C; Tryland, Morten",Virol J,,,,document_parses/pdf_json/7b9e45133c8a6f6c48ec8c5f1f0c01ad0cd1d3ae.json,document_parses/pmc_json/PMC3042955.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3042955/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3042955',
#      'abstract': 'Avipoxviruses (APVs) belong to the Chordopoxvirinae subfamily of the Poxviridae family. APVs are distributed worldwide and cause disease in domestic, pet and wild birds of many species. APVs are transmitted by aerosols and biting insects, particularly mosquitoes and arthropods and are usually named after the bird species from which they were originally isolated. The virus species Fowlpox virus (FWPV) causes disease in poultry and associated mortality is usually low, but in flocks under stress (other diseases, high production) mortality can reach up to 50%. APVs are also major players in viral vaccine vector development for diseases in human and veterinary medicine. Abortive infection in mammalian cells (no production of progeny viruses) and their ability to accommodate multiple gene inserts are some of the characteristics that make APVs promising vaccine vectors. Although abortive infection in mammalian cells conceivably represents a major vaccine bio-safety advantage, molecular mechanisms restricting APVs to certain hosts are not yet fully understood. This review summarizes the current knowledge relating to APVs, including classification, morphogenesis, host-virus interactions, diagnostics and disease, and also highlights the use of APVs as recombinant vaccine vectors.',
#      'publish_time': '2011-02-03',
#      'journal': 'Virol J',
#      'pdf_json_files': 'document_parses/pdf_json/7b9e45133c8a6f6c48ec8c5f1f0c01ad0cd1d3ae.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'VmUN-XMBkX4i4bZkAnGc',
#     '_score': 0.9300287,
#     '_source': {'path': '/home/varun/metadata.csv',
#      'source_x': 'PMC',
#      'sha': '164f0fed97b05b34ea5df0f4e4e9e204d05f7849',
#      'title': 'Apolipoprotein M Gene (APOM) Polymorphism Modifies Metabolic and Disease Traits in Type 2 Diabetes',
#      '@timestamp': '2020-08-16T20:54:02.073Z',
#      's2_id': None,
#      'pubmed_id': '21390319',
#      'cord_uid': 'a18rch1f',
#      'authors': 'Zhou, Jun-Wei; Tsui, Stephen K. W.; Ng, Maggie C. Y.; Geng, Hua; Li, Sai-Kam; So, Wing-Yee; Ma, Ronald C.; Wang, Ying; Tao, Qian; Chen, Zhen-Yu; Chan, Juliana C. N.; Ho, Yuan-Yuan',
#      'pmc_json_files': 'document_parses/pmc_json/PMC3044746.xml.json',
#      'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3044746/',
#      'doi': '10.1371/journal.pone.0017324',
#      'host': 'kaggle-task',
#      'message': 'a18rch1f,164f0fed97b05b34ea5df0f4e4e9e204d05f7849,PMC,Apolipoprotein M Gene (APOM) Polymorphism Modifies Metabolic and Disease Traits in Type 2 Diabetes,10.1371/journal.pone.0017324,PMC3044746,21390319,cc-by,"This study aimed at substantiating the associations of the apolipoproein M gene (APOM) with type 2 diabetes (T2D) as well as with metabolic traits in Hong Kong Chinese. In addition, APOM gene function was further characterized to elucidate its activity in cholesterol metabolism. Seventeen APOM SNPs documented in the NCBI database were genotyped. Five SNPs were confirmed in our study cohort of 1234 T2D and 606 control participants. Three of the five SNPs rs707921(C+1871A), rs707922(G+1837T) and rs805264(G+203A) were in linkage disequilibrium (LD). We chose rs707922 to tag this LD region for down stream association analyses and characterized the function of this SNP at molecular level. No association between APOM and T2D susceptibility was detected in our Hong Kong Chinese cohort. Interestingly, the C allele of rs805297 was significantly associated with T2D duration of longer than 10 years (OR = 1.245, p = 0.015). The rs707922 TT genotype was significantly associated with elevated plasma total- and LDL- cholesterol levels (p = 0.006 and p = 0.009, respectively) in T2D patients. Molecular analyses of rs707922 lead to the discoveries of a novel transcript APOM5 as well as the cryptic nature of exon 5 of the gene. Ectopic expression of APOM5 transcript confirmed rs707922 allele-dependent activity of the transcript in modifying cholesterol homeostasis in vitro. In conclusion, the results here did not support APOM as a T2D susceptibility gene in Hong Kong Chinese. However, in T2D patients, a subset of APOM SNPs was associated with disease duration and metabolic traits. Further molecular analysis proved the functional activity of rs707922 in APOM expression and in regulation of cellular cholesterol content.",2011-02-24,"Zhou, Jun-Wei; Tsui, Stephen K. W.; Ng, Maggie C. Y.; Geng, Hua; Li, Sai-Kam; So, Wing-Yee; Ma, Ronald C.; Wang, Ying; Tao, Qian; Chen, Zhen-Yu; Chan, Juliana C. N.; Ho, Yuan-Yuan",PLoS One,,,,document_parses/pdf_json/164f0fed97b05b34ea5df0f4e4e9e204d05f7849.json,document_parses/pmc_json/PMC3044746.xml.json,https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3044746/,\r',
#      'license': 'cc-by',
#      'pmcid': 'PMC3044746',
#      'abstract': 'This study aimed at substantiating the associations of the apolipoproein M gene (APOM) with type 2 diabetes (T2D) as well as with metabolic traits in Hong Kong Chinese. In addition, APOM gene function was further characterized to elucidate its activity in cholesterol metabolism. Seventeen APOM SNPs documented in the NCBI database were genotyped. Five SNPs were confirmed in our study cohort of 1234 T2D and 606 control participants. Three of the five SNPs rs707921(C+1871A), rs707922(G+1837T) and rs805264(G+203A) were in linkage disequilibrium (LD). We chose rs707922 to tag this LD region for down stream association analyses and characterized the function of this SNP at molecular level. No association between APOM and T2D susceptibility was detected in our Hong Kong Chinese cohort. Interestingly, the C allele of rs805297 was significantly associated with T2D duration of longer than 10 years (OR = 1.245, p = 0.015). The rs707922 TT genotype was significantly associated with elevated plasma total- and LDL- cholesterol levels (p = 0.006 and p = 0.009, respectively) in T2D patients. Molecular analyses of rs707922 lead to the discoveries of a novel transcript APOM5 as well as the cryptic nature of exon 5 of the gene. Ectopic expression of APOM5 transcript confirmed rs707922 allele-dependent activity of the transcript in modifying cholesterol homeostasis in vitro. In conclusion, the results here did not support APOM as a T2D susceptibility gene in Hong Kong Chinese. However, in T2D patients, a subset of APOM SNPs was associated with disease duration and metabolic traits. Further molecular analysis proved the functional activity of rs707922 in APOM expression and in regulation of cellular cholesterol content.',
#      'publish_time': '2011-02-24',
#      'journal': 'PLoS One',
#      'pdf_json_files': 'document_parses/pdf_json/164f0fed97b05b34ea5df0f4e4e9e204d05f7849.json',
#      '@version': '1',
#      'who_covidence_id': None,
#      'arxiv_id': None,
#      'mag_id': None}}]}}

# %%
pub_date = es.search(index="metafile", body={"_source": ["title"], 
                                     "query": {"range": 
                                               {"publish_time": 
                                                {"lt":"2020-01-01"}}}})


pub_date
# Out:
# {'took': 42,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'TWUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Spatial dynamics of the 1918 influenza pandemic in England, Wales and the United States'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'TmUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Charge-Surrounded Pockets and Electrostatic Interactions with Small Ions Modulate the Activity of Retroviral Fusion Proteins'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'T2UN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Tracheostomy and mechanical ventilation weaning in children affected by respiratory virus according to a weaning protocol in a pediatric intensive care unit in Argentina: an observational restrospective trial'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'UGUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'The activity of the HIV-1 IRES is stimulated by oxidative stress and controlled by a negative regulatory element'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'UWUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Further Characterisation of the Translational Termination-Reinitiation Signal of the Influenza B Virus Segment 7 RNA'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'UmUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'RNA and DNA Bacteriophages as Molecular Diagnosis Controls in Clinical Virology: A Comprehensive Study of More than 45,000 Routine PCR Tests'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'U2UN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Pandemic H1N1 2009 influenza virus with the H275Y oseltamivir resistance neuraminidase mutation shows a small compromise in enzyme activity and viral fitness'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'VGUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Ketamine inhibits tumor necrosis factor secretion by RAW264.7 murine macrophages stimulated with antibiotic-exposed strains of community-associated, methicillin-resistant Staphylococcus aureus'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'VWUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Avipoxviruses: infection biology and their use as vaccine vectors'}},
#    {'_index': 'metafile',
#     '_type': '_doc',
#     '_id': 'VmUN-XMBkX4i4bZkAnGc',
#     '_score': 1.0,
#     '_source': {'title': 'Apolipoprotein M Gene (APOM) Polymorphism Modifies Metabolic and Disease Traits in Type 2 Diabetes'}}]}}
